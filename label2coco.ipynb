# %%
# !pip install -U labelme2coco
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 81 kB 4.6 MB/s
# ...
#      |████████████████████████████████| 60.5 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 97 kB 6.3 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 41.8 MB/s
# ...
#      |████████████████████████████████| 87 kB 6.4 MB/s
# ...
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115942 sha256=bc0997e5381460bb95a0698eebd632c12abffdd7a1332b76c009e4dc12870596
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# Successfully built fire
# ...
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from labelme2coco import get_coco_from_labelme_folder,save_json

labelme_train_folder = '/content/drive/MyDrive/Colab Notebooks/output/data_annotated-1-67/'

labelme_test_folder = '/content/drive/MyDrive/Colab Notebooks/output/data_annotated/'

export_dir = '/content/drive/MyDrive/Colab Notebooks/output'

train_coco = get_coco_from_labelme_folder(labelme_train_folder)

save_json(train_coco.json,export_dir+'/train_co.json')

val_coco = get_coco_from_labelme_folder(labelme_test_folder,coco_category_list=train_coco.json_categories)

save_json(val_coco.json,export_dir+'/val_co.json')
# Out:
# There are 66 listed files in folder .
# Converting labelme annotations to COCO format: 100%|██████████| 66/66 [00:00<00:00, 77.50it/s]
# There are 103 listed files in folder .
# Converting labelme annotations to COCO format: 100%|██████████| 103/103 [00:01<00:00, 96.67it/s]
